# %% [markdown]
# <a href="https://colab.research.google.com/github/JeyyGit/machine-learning-tasks/blob/main/week_2/Regression_PH_House_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nama: Jaisy Malikulmulki Arasy
# NIM: 1103202201
# Tugas 2
# Regression PH House Price

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# path file csv
file_path = '/content/drive/My Drive/Dataset/PH_houses_v2.csv'

df = pd.read_csv(file_path, delimiter=';')
df.head()
# Out:
#    Price (PHP)  Bedrooms  Floor_area (sqm)   Latitude   Longitude
# 0     15916180         2                74  103051555  1240112408
# 1      8730355         1                41  103051555  1240112408
# 2     16011000         1                58   14588882   121079016
# 3      1935600         3                40    1435507   120876425
# 4      7587013         1                32   14578255   121052143

# %%
df.describe()
# Out:
#         Price (PHP)    Bedrooms  Floor_area (sqm)      Latitude     Longitude
# count  1.490000e+02  149.000000        149.000000  1.490000e+02  1.490000e+02
# mean   1.430686e+07    1.530201         60.825503  2.113380e+07  1.028187e+09
# std    7.104073e+06    1.049820         22.495865  2.586299e+07  1.013885e+10
# min    1.918427e+06    1.000000         22.000000  1.031589e+06  1.205482e+07
# 25%    8.967000e+06    1.000000         53.000000  1.457582e+07  1.210643e+08
# 50%    1.560100e+07    1.000000         57.000000  1.458888e+07  1.210790e+08
# 75%    1.642000e+07    2.000000         66.000000  1.458888e+07  1.210790e+08
# max    3.512100e+07    5.000000        166.000000  1.487440e+08  1.239060e+11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price (PHP)       149 non-null    int64
#  1   Bedrooms          149 non-null    int64
#  2   Floor_area (sqm)  149 non-null    int64
#  3   Latitude          149 non-null    int64
#  4   Longitude         149 non-null    int64
# dtypes: int64(5)
# memory usage: 5.9 KB

# %%
# pemisahan atribut dengan label
predictions = ['Bedrooms', 'Floor_area (sqm)']
X = df[predictions]
y = df['Price (PHP)']

# %%
# normalisasi data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X)
scaled_data = scaler.transform(X)
scaled_data = pd.DataFrame(scaled_data, columns = X.columns)
scaled_data.head()
# Out:
#    Bedrooms  Floor_area (sqm)
# 0  0.449013          0.587616
# 1 -0.506744         -0.884268
# 2 -0.506744         -0.126025
# 3  1.404770         -0.928870
# 4 -0.506744         -1.285691

# %%
# membagi data menjadi train dan test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(scaled_data, y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# membuat model regresi linear dan melatih dengan fit
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# menguji akurasi model
model.score(X_test, y_test)
# Out:
# 0.7722956113851744
